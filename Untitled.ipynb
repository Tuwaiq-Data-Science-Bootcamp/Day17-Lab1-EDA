# %%
## Import libraries to read dataset named Loan Default
## Import proper statistical library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Loan_Defaults.csv", index_col=0)
df
# Out:
#           DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# UNIQUEID
# 655269               53478       63558  86.54         67        22807
# 723482               55513       63163  89.45         67        22807
# 758529               65282       84320  79.93         78        23135
# 763449               46905       63896  76.58         78        17014
# 708663               51428       63896  86.08         78        17014
# ...                    ...         ...    ...        ...          ...
# 755547               44875       72509  67.58         74        16646
# 716994               53549       72509  78.61         74        16646
# 709352               55243       72509  81.37         74        16646
# 699795               55243       72509  81.37         74        16646
# 755244               40274       72509  60.68         74        16646
#
#           MANUFACTURER_ID  CURRENT_PINCODE_ID DATE_OF_BIRTH EMPLOYMENT_TYPE  \
# UNIQUEID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112392 entries, 655269 to 755244
# Data columns (total 39 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   DISBURSED_AMOUNT                     112392 non-null  int64
#  1   ASSET_COST                           112392 non-null  int64
#  2   LTV                                  112392 non-null  float64
#  3   BRANCH_ID                            112392 non-null  int64
#  4   SUPPLIER_ID                          112392 non-null  int64
#  5   MANUFACTURER_ID                      112392 non-null  int64
#  6   CURRENT_PINCODE_ID                   112392 non-null  int64
#  7   DATE_OF_BIRTH                        112392 non-null  object
#  8   EMPLOYMENT_TYPE                      108949 non-null  object
#  9   DISBURSAL_DATE                       112392 non-null  object
#  10  STATE_ID                             112392 non-null  int64
# ...

# %% [markdown]
# <h1 style="color:green">1- Univariate analysis</h1>

# %%
df['LTV'].describe()
# Out:
# count    112392.000000
# mean         75.310325
# std          11.006380
# min          10.030000
# 25%          69.970000
# 50%          77.780000
# 75%          83.740000
# max          95.000000
# Name: LTV, dtype: float64

# %%
df['LTV'].mode()
# Out:
# 0    85.0
# dtype: float64

# %% [markdown]
# <h6 style="color:green">(LTV) Loan-To-Value Ratio

# %% [markdown]
# (the typical LTV is between 75-85) <br>
# mean:75 <br>
# median:77 <br>
# mode:85 <br>
# std:11<br>
#
# -<b>The data is slightly skewed to the left</b>.
# -Mean value is less than median, and Mode is bigger.
#
# -smaller standard deviation implies </b>that the data points are more crowded around the mean</b>, which means less extreme values
#
# However, min=10 max=95
# means <b>the data has outliers which can change the results of the data analysis and statistical modeling</b>

# %%
df['LTV'].plot.kde();
#the diagram shows how the data is slightly skewed to the left
#the data points are more crowded around the mean, which means less extreme values

# %%
plt.boxplot(df['LTV']);
#the diagram shows that the data has outliers 
#which can change the results of the data analysis and statistical modeling

# %% [markdown]
# <h1 style="color:green">2-Multivariate analysis

# %% [markdown]
# <h6 style="color:green">((LTV) Loan-To-Value Ratio) & (DISBURSED_AMOUNT)

# %%
sns.heatmap(df.corr()); #heatmap to study correlations
# the map shows that most data has no correlation since they are close to zero
# where if the the correlation closer to 1 , there is a relation

# %%
plt.scatter(df['LTV'],df['DISBURSED_AMOUNT']);
#th diagram shows strong correlation 
#the closer the dots together, the stronger the correlation.
#positive relationship

#data points overlap to a degree where we have difficulty seeing relationships between points and variables.
#overlap means that the two samples values are dependent o each other.

#Strong, Positive, Linear
