# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Loan_Defaults.csv")
df.head()
# Out:
#    UNIQUEID  DISBURSED_AMOUNT  ASSET_COST    LTV  BRANCH_ID  SUPPLIER_ID  \
# 0    655269             53478       63558  86.54         67        22807
# 1    723482             55513       63163  89.45         67        22807
# 2    758529             65282       84320  79.93         78        23135
# 3    763449             46905       63896  76.58         78        17014
# 4    708663             51428       63896  86.08         78        17014
#
#    MANUFACTURER_ID  CURRENT_PINCODE_ID DATE_OF_BIRTH EMPLOYMENT_TYPE  ...  \
# 0               45                1497    01-01-1974        Salaried  ...
# 1               45                1497    20-05-1985   Self employed  ...
# 2               86                2071    14-10-1995        Salaried  ...
# 3               45                2070    01-06-1973   Self employed  ...
# 4               45                2069    01-06-1972        Salaried  ...
#
#   SEC_CURRENT_BALANCE  SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  \
# ...

# %%
df.columns
# Out:
# Index(['UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'BRANCH_ID',
#        'SUPPLIER_ID', 'MANUFACTURER_ID', 'CURRENT_PINCODE_ID', 'DATE_OF_BIRTH',
#        'EMPLOYMENT_TYPE', 'DISBURSAL_DATE', 'STATE_ID', 'EMPLOYEE_CODE_ID',
#        'MOBILENO_AVL_FLAG', 'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG',
#        'DRIVING_FLAG', 'PASSPORT_FLAG', 'PERFORM_CNS_SCORE',
#        'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_NO_OF_ACCTS', 'PRI_ACTIVE_ACCTS',
#        'PRI_OVERDUE_ACCTS', 'PRI_CURRENT_BALANCE', 'PRI_SANCTIONED_AMOUNT',
#        'PRI_DISBURSED_AMOUNT', 'SEC_NO_OF_ACCTS', 'SEC_ACTIVE_ACCTS',
#        'SEC_OVERDUE_ACCTS', 'SEC_CURRENT_BALANCE', 'SEC_SANCTIONED_AMOUNT',
#        'SEC_DISBURSED_AMOUNT', 'PRIMARY_INSTAL_AMT', 'SEC_INSTAL_AMT',
#        'NEW_ACCTS_IN_LAST_SIX_MONTHS', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
#        'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES'],
#       dtype='object')

# %%
df_date = df["DATE_OF_BIRTH"].str.split('-',n=2,expand=True).astype(int)
df_date.head()
# Out:
#     0   1     2
# 0   1   1  1974
# 1  20   5  1985
# 2  14  10  1995
# 3   1   6  1973
# 4   1   6  1972

# %% [markdown]
# ## The Disbrused amount for number of Loans/ filtred by number of loans returned

# %%
sns.set(rc={"figure.figsize":(10, 10)})

sns.scatterplot(data=df, x="DISBURSED_AMOUNT",y="SEC_NO_OF_ACCTS", hue='NO_OF_INQUIRIES');

# %% [markdown]
# ## The Asset given Value as the Cost of it

# %%
sns.scatterplot(data=df, x="ASSET_COST", y="LTV");

# %% [markdown]
# ## Number of Loans in the last 6 months for the total number of Loans

# %%
sns.lineplot(data=df, x="SEC_NO_OF_ACCTS", y='NEW_ACCTS_IN_LAST_SIX_MONTHS');

# %% [markdown]
# ## Number of Loans as the Employment type / filtered by: how many loans in the last 6 months

# %%
sns.barplot(data=df, y="SEC_NO_OF_ACCTS", x='EMPLOYMENT_TYPE', hue='NEW_ACCTS_IN_LAST_SIX_MONTHS');
